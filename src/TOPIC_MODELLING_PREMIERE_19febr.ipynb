# %% [markdown]
# # 19 February summary:
#
# COHERENCE SCORE for 12 topics: 0.59 (highest coherence value)
#
# |     Topic    |     Keywords                                                                                                                                                    |
# |--------------|-----------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |     1        |     Tonight,   love, late, great, day, thing, world, chat, documentary, big night, spend,   outage, cool, thereidout, hear                                      |
# |     2        |     Film, music,   project, currently looke, game animation, gl, visit http, rainsdowne players,   poster, the new, literally, artist, surprise, hire, light    |
# |     3        |     Join, good,   year, set, lot, bad, movie, remake, put, boy, franchise, stuff, forget, speak,   icymi                                                        |
# |     4        |     Podcast, time, listen, discuss, work, stream,   character, end, finally, issue, video, version, publish, meet, fun                                         |
# |     5        |     Watch, live,   favorite, genre, bobcore, share, feel, tweet, honor, song, dark, follow,   episode, cast, line                                               |
# |     6        |     Show, supergirl, young, dc_universe, original, pick,   season, tomorrow, full, enjoy, tune, game, ready, action, give                                   |
# |     7        |    <b>Wandavision, release, spoiler, wanda_thevision, impact,   word, amazing, reveal, power, hope, cat, powerful_avenger, king, yup, scene    <b>                   |
# |     8        |     Movie, make,   trailer, video, guest, uhg, skydance, cover, special, trustmovie, owen, hard,   support, art, great                                          |
# |     9        |     Brand, today,   feature, back, drop, friend, send, people, long, link, break, couple, family,   expe, free                                                  |
# |     10       |     Talk, accountability,   terrify, republicans_complain, find, life, big, night, start, play, story,   hit, flash, win, guy                                   |
# |     11       |     Film, week,   amp, bring, wait, direct, business, job, support existe, mone, team,   goldfinger, adaptation, running man, call                              |
#
#
# In this date we find wandavision as one of the most frequent words. The topic is well defined with the high-coherence number of topics of 11. Another topic that makes sense is the Topic.6 which is about the Supergirl show.

# %% [markdown]
# # **Topic modelling process for one batch of tweets**
#
# Most of the code was provided by the lab session on the "Topic Modelling" lecture. However, there are some changes to adapt the procedure to our datasets. For example, we do a previous study on most and least frequent words.
#
# This procedure cleans the text from the least used words, the usernames, the usual stopwords (with specific twitter words such as 'https','rt', and 'co') and the words that are directly from the search. It also creates and applies bigram and trigram models and lemmatizes the text. Finally, it applies and LDA Mallet Model, that together with a coherence study, returns the optimal number of topics and their keywords. We save the obtained topics.
#
# Finally, to do some checking on the model we review the dominant topics in different tweets.

# %% [markdown]
# ## Import Packages and Data
# The core packages used in this tutorial are **gensim**, and **pyLDAvis**. Besides this we will also using _re_, _matplotlib_, _numpy_ and _pandas_ for data handling and visualization. Let’s import them.

# %%
import nltk
from nltk.corpus import stopwords 
nltk.download('stopwords')

import re
import numpy as np
import pandas as pd
from pprint import pprint
import json
import matplotlib.pyplot as plt 
from nltk.tokenize import RegexpTokenizer



# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# spacy for lemmatization
import spacy

# Plotting tools
# !pip install pyLDAvis
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Collecting pyLDAvis
#   Downloading https://files.pythonhosted.org/packages/24/38/6d81eff34c84c9158d3b7c846bff978ac88b0c2665548941946d3d591158/pyLDAvis-3.2.2.tar.gz (1.7MB)
#      |████████████████████████████████| 1.7MB 5.8MB/s
# Requirement already satisfied: wheel>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.36.2)
# Requirement already satisfied: numpy>=1.9.2 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.19.5)
# Requirement already satisfied: scipy>=0.18.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.4.1)
# Requirement already satisfied: joblib>=0.8.4 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.0.1)
# Requirement already satisfied: jinja2>=2.7.2 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.11.3)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.7.3)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.16.0)
# Collecting funcy
#   Downloading https://files.pythonhosted.org/packages/66/89/479de0afbbfb98d1c4b887936808764627300208bb771fcd823403645a36/funcy-1.15-py2.py3-none-any.whl
# Requirement already satisfied: pandas>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.1.5)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2>=2.7.2->pyLDAvis) (1.1.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.17.0->pyLDAvis) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.17.0->pyLDAvis) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.17.0->pyLDAvis) (1.15.0)
# Building wheels for collected packages: pyLDAvis
#   Building wheel for pyLDAvis (setup.py) ... done
#   Created wheel for pyLDAvis: filename=pyLDAvis-3.2.2-py2.py3-none-any.whl size=135593 sha256=93861a7ec51088717191a39589b169c1e05adf3d6c1b777d5621e6ae07d07072
#   Stored in directory: /root/.cache/pip/wheels/74/df/b6/97234c8446a43be05c9a8687ee0db1f1b5ade5f27729187eae
# Successfully built pyLDAvis
# Installing collected packages: funcy, pyLDAvis
# Successfully installed funcy-1.15 pyLDAvis-3.2.2
# /usr/local/lib/python3.7/dist-packages/past/types/oldstr.py:5: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Iterable

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Tweets collected from ['premiere','new movie','new episode', 'new film'] search
#
# This is imported using _pandas.read_json_

# %%
# Import Dataset
with open('/content/drive/Shareddrives/WebIntelligence/DATA/Twitter/premiere19FEB.jsonl') as f:
    lines = f.read().splitlines()
df_inter = pd.DataFrame(lines)
df_inter.columns = ['json_element']    
df_inter['json_element'].apply(json.loads)
df = pd.json_normalize(df_inter['json_element'].apply(json.loads))

# Keep only the tweets in English
df = df[df.lang=='en']

# Create URL field for tweets
df['url'] = 'https://twitter.com/_/status/'+df['id_str']

df.head(5)
# Out:
#                        created_at                   id               id_str  \
# 0  Fri Feb 19 21:47:16 +0000 2021  1362881462073188363  1362881462073188363
# 1  Fri Feb 19 21:47:16 +0000 2021  1362881462748524548  1362881462748524548
# 2  Fri Feb 19 21:47:17 +0000 2021  1362881466766667786  1362881466766667786
# 3  Fri Feb 19 21:47:18 +0000 2021  1362881471409770496  1362881471409770496
# 4  Fri Feb 19 21:47:20 +0000 2021  1362881480930717699  1362881480930717699
#
#                                                                                                                                               text  \
# 0   RT @MCU_Direct: WARNING - SPOILERS BELOW:\n\nA brief frame during #WandaVision's new episode offered more insight into #SWORD's plan with #Th…
# 1                                                                       RT @Joshuagumi: New JJK episode had me sketching 😼 https://t.co/JYWUwrTxda
# 2  #107DaysOfGenocide since joint forces of the #Ethiopian &amp; #Eritrean gov’ts started to exterminate ethnic Tigrayans… https://t.co/Mu9CJh405z
# 3     RT @TCP_Pod: The new documentary about the late, great Patrice O’Neal premieres tonight on Comedy Central.  We went over some of his lesson…
# 4                                                 RT @lilyachty: ALSO NEW EPISODE OF THE BOAT SHOW https://t.co/kTZJ6qpSTb https://t.co/5LLCu546hq
#
#                                                                                source  \
# 0             <a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3
# 4  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
#    truncated  in_reply_to_status_id in_reply_to_status_id_str  \
# 0      False                    NaN                      None
# 1      False                    NaN                      None
# 2       True                    NaN                      None
# 3      False                    NaN                      None
# 4      False                    NaN                      None
#
#    in_reply_to_user_id in_reply_to_user_id_str in_reply_to_screen_name  geo  \
# 0                  NaN                    None                    None  NaN
# 1                  NaN                    None                    None  NaN
# 2                  NaN                    None                    None  NaN
# 3                  NaN                    None                    None  NaN
# 4                  NaN                    None                    None  NaN
#
#    coordinates  place contributors  is_quote_status  quote_count  reply_count  \
# 0          NaN    NaN         None            False            0            0
# 1          NaN    NaN         None            False            0            0
# 2          NaN    NaN         None            False            0            0
# 3          NaN    NaN         None            False            0            0
# 4          NaN    NaN         None            False            0            0
#
#    retweet_count  favorite_count  favorited  retweeted filter_level lang  \
# 0              0               0      False      False          low   en
# 1              0               0      False      False          low   en
# 2              0               0      False      False          low   en
# 3              0               0      False      False          low   en
# 4              0               0      False      False          low   en
#
#     timestamp_ms              user.id          user.id_str  user.name  \
# 0  1613771236328   924732546826604549   924732546826604549   Mariusz_
# 1  1613771236489   732015104741376001   732015104741376001    drew :3
# 2  1613771237447  1327180829341196288  1327180829341196288      Selma
# 3  1613771238554  1154876846749523968  1154876846749523968  PodNation
# 4  1613771240824           1512352380           1512352380    rodrigo
#
#   user.screen_name user.location  \
# 0       S_Mariusz_        Polska
# 1         imersity          None
# 2        selma_224        London
# 3    PodNationPods          None
# 4     rodriigocoba       Ecuador
#
#                                                             user.url  \
# 0                                                               None
# 1                                                               None
# 2                                              http://omnatigray.org
# 3               https://www.podchaser.com/lists/PodNation-107Zzr3XOD
# 4  https://twitter.com/pde_youngnudy/status/1240814450179018753?s=21
#
#                                                                                                                                         user.description  \
# 0                                                                                                                       #StarWars fan and #MCU movies 🎥🎬
# 1                              17 || Laid back Camper || Probably drawing or playing osu || Cw: Gintama/ New Game!/ Made In Abyss || Cr: Houseki no kuni
# 2                                                                                                                                                   None
# 3  Take me to your podcasts! \n\nLet's build a community by using #PodNation\n\nFinding passionate podcasters all over the world! 👽 Before we take over!
# 4                                                                                                                                    🦷| IG: rodriigocoba
#
#   user.translator_type  user.protected  user.verified  user.followers_count  \
# 0                 none           False          False                    61
# 1                 none           False          False                   544
# 2                 none           False          False                   126
# 3                 none           False          False                  7123
# 4                 none           False          False                   585
#
#    user.friends_count  user.listed_count  user.favourites_count  \
# 0                  14                  0                  12095
# 1                 297                  6                  30782
# 2                 239                  0                     24
# 3                4444                 60                  22513
# 4                 498                  3                  45922
#
#    user.statuses_count                 user.created_at user.utc_offset  \
# 0                10175  Sun Oct 29 20:19:54 +0000 2017            None
# 1                12043  Mon May 16 01:09:35 +0000 2016            None
# 2                  155  Fri Nov 13 09:26:10 +0000 2020            None
# 3                28810  Fri Jul 26 22:11:11 +0000 2019            None
# 4                21121  Thu Jun 13 04:21:16 +0000 2013            None
#
#   user.time_zone  user.geo_enabled user.lang  user.contributors_enabled  \
# 0           None             False      None                      False
# 1           None             False      None                      False
# 2           None             False      None                      False
# 3           None             False      None                      False
# 4           None              True      None                      False
#
#    user.is_translator user.profile_background_color  \
# 0               False                        F5F8FA
# 1               False                        F5F8FA
# 2               False                        F5F8FA
# 3               False                        F5F8FA
# 4               False                        ABB8C2
#
#                    user.profile_background_image_url  \
# 0
# 1
# 2
# 3
# 4  http://abs.twimg.com/images/themes/theme15/bg.png
#
#               user.profile_background_image_url_https  \
# 0
# 1
# 2
# 3
# 4  https://abs.twimg.com/images/themes/theme15/bg.png
#
#    user.profile_background_tile user.profile_link_color  \
# 0                         False                  1DA1F2
# 1                         False                  1DA1F2
# 2                         False                  1DA1F2
# 3                         False                  1DA1F2
# 4                         False                  ABB8C2
#
#   user.profile_sidebar_border_color user.profile_sidebar_fill_color  \
# 0                            C0DEED                          DDEEF6
# 1                            C0DEED                          DDEEF6
# 2                            C0DEED                          DDEEF6
# 3                            C0DEED                          DDEEF6
# 4                            FFFFFF                          C0DFEC
#
#   user.profile_text_color  user.profile_use_background_image  \
# 0                  333333                               True
# 1                  333333                               True
# 2                  333333                               True
# 3                  333333                               True
# 4                  333333                              False
#
#                                                         user.profile_image_url  \
# 0  http://pbs.twimg.com/profile_images/1315759828460081154/za5LDIDd_normal.jpg
# 1  http://pbs.twimg.com/profile_images/1357219428467945473/R1gGYqGg_normal.jpg
# 2  http://pbs.twimg.com/profile_images/1360718675377070081/OB3qkcZ__normal.jpg
# 3  http://pbs.twimg.com/profile_images/1233799138271039489/V3raAtLf_normal.jpg
# 4  http://pbs.twimg.com/profile_images/1203846321347514368/XqVySAMD_normal.jpg
#
#                                                    user.profile_image_url_https  \
# 0  https://pbs.twimg.com/profile_images/1315759828460081154/za5LDIDd_normal.jpg
# 1  https://pbs.twimg.com/profile_images/1357219428467945473/R1gGYqGg_normal.jpg
# 2  https://pbs.twimg.com/profile_images/1360718675377070081/OB3qkcZ__normal.jpg
# 3  https://pbs.twimg.com/profile_images/1233799138271039489/V3raAtLf_normal.jpg
# 4  https://pbs.twimg.com/profile_images/1203846321347514368/XqVySAMD_normal.jpg
#
#                                                 user.profile_banner_url  \
# 0   https://pbs.twimg.com/profile_banners/924732546826604549/1602536564
# 1   https://pbs.twimg.com/profile_banners/732015104741376001/1612191437
# 2  https://pbs.twimg.com/profile_banners/1327180829341196288/1605874456
# 3  https://pbs.twimg.com/profile_banners/1154876846749523968/1576989884
# 4           https://pbs.twimg.com/profile_banners/1512352380/1599884850
#
#    user.default_profile  user.default_profile_image user.following  \
# 0                  True                       False           None
# 1                  True                       False           None
# 2                  True                       False           None
# 3                  True                       False           None
# 4                 False                       False           None
#
#   user.follow_request_sent user.notifications     retweeted_status.created_at  \
# 0                     None               None  Fri Feb 19 18:36:50 +0000 2021
# 1                     None               None  Fri Feb 19 21:46:37 +0000 2021
# 2                     None               None                             NaN
# 3                     None               None  Fri Feb 19 21:40:57 +0000 2021
# 4                     None               None  Fri Feb 19 05:33:50 +0000 2021
#
#    retweeted_status.id retweeted_status.id_str  \
# 0         1.362834e+18     1362833539776081923
# 1         1.362881e+18     1362881298717638657
# 2                  NaN                     NaN
# 3         1.362880e+18     1362879875099500544
# 4         1.362636e+18     1362636488408788998
#
#                                                                                                                            retweeted_status.text  \
# 0  WARNING - SPOILERS BELOW:\n\nA brief frame during #WandaVision's new episode offered more insight into #SWORD's plan… https://t.co/a1dOZxEgfT
# 1                                                                                     New JJK episode had me sketching 😼 https://t.co/JYWUwrTxda
# 2                                                                                                                                            NaN
# 3   The new documentary about the late, great Patrice O’Neal premieres tonight on Comedy Central.  We went over some of… https://t.co/GNnUeglEKO
# 4                                                              ALSO NEW EPISODE OF THE BOAT SHOW https://t.co/kTZJ6qpSTb https://t.co/5LLCu546hq
#
#   retweeted_status.display_text_range  \
# 0                            [0, 140]
# 1                             [0, 34]
# 2                                 NaN
# 3                                 NaN
# 4                             [0, 57]
#
#                                                               retweeted_status.source  \
# 0                              <a href="https://buffer.com" rel="nofollow">Buffer</a>
# 1             <a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>
# 2                                                                                 NaN
# 3  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 4  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
#   retweeted_status.truncated  retweeted_status.in_reply_to_status_id  \
# 0                       True                                     NaN
# 1                      False                                     NaN
# 2                        NaN                                     NaN
# 3                       True                                     NaN
# 4                      False                                     NaN
#
#   retweeted_status.in_reply_to_status_id_str  \
# 0                                       None
# 1                                       None
# 2                                        NaN
# 3                                       None
# 4                                       None
#
#    retweeted_status.in_reply_to_user_id  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   retweeted_status.in_reply_to_user_id_str  \
# 0                                     None
# 1                                     None
# 2                                      NaN
# 3                                     None
# 4                                     None
#
#   retweeted_status.in_reply_to_screen_name  retweeted_status.user.id  \
# 0                                     None              8.469234e+17
# 1                                     None              1.296871e+18
# 2                                      NaN                       NaN
# 3                                     None              1.065844e+18
# 4                                     None              1.751984e+08
#
#   retweeted_status.user.id_str     retweeted_status.user.name  \
# 0           846923375209594880               MCU - The Direct
# 1          1296870908716634112                           Josh
# 2                          NaN                            NaN
# 3          1065843842224508928                 Lakers (49-14)
# 4                    175198393  concrete boy boat/ most hated
#
#   retweeted_status.user.screen_name retweeted_status.user.location  \
# 0                        MCU_Direct                           None
# 1                        Joshuagumi                      Ikebukuro
# 2                               NaN                            NaN
# 3                           TCP_Pod                           None
# 4                         lilyachty                           None
#
#                  retweeted_status.user.url  \
# 0                 http://www.thedirect.com
# 1                                     None
# 2                                      NaN
# 3  https://anchor.fm/completelakerspodcast
# 4                                     None
#
#                                                                      retweeted_status.user.description  \
# 0   The best source for Marvel Cinematic Universe news and quality content! The MCU home of @TheDirect
# 1                                                            Lover of stories\n\nAvi- @/mumei__chan__0
# 2                                                                                                  NaN
# 3  Anthony Wilson and two other guys bring you another podcast by random dudes talking about whatever.
# 4                                                                                             it’s us!
#
#   retweeted_status.user.translator_type retweeted_status.user.protected  \
# 0                                  none                           False
# 1                                  none                           False
# 2                                   NaN                             NaN
# 3                                  none                           False
# 4                                  none                           False
#
#   retweeted_status.user.verified  retweeted_status.user.followers_count  \
# 0                          False                               619832.0
# 1                          False                                  685.0
# 2                            NaN                                    NaN
# 3                          False                                 1391.0
# 4                           True                              5351352.0
#
#    retweeted_status.user.friends_count  retweeted_status.user.listed_count  \
# 0                                109.0                              1218.0
# 1                                259.0                                11.0
# 2                                  NaN                                 NaN
# 3                               1761.0                                 5.0
# 4                                716.0                              1323.0
#
#    retweeted_status.user.favourites_count  \
# 0                                     2.0
# 1                                 20881.0
# 2                                     NaN
# 3                                    26.0
# 4                                 15285.0
#
#    retweeted_status.user.statuses_count retweeted_status.user.created_at  \
# 0                                7795.0   Wed Mar 29 03:14:02 +0000 2017
# 1                               12782.0   Fri Aug 21 18:05:07 +0000 2020
# 2                                   NaN                              NaN
# 3                                2583.0   Fri Nov 23 05:45:49 +0000 2018
# 4                               51321.0   Thu Aug 05 23:34:12 +0000 2010
#
#    retweeted_status.user.utc_offset  retweeted_status.user.time_zone  \
# 0                               NaN                              NaN
# 1                               NaN                              NaN
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4                               NaN                              NaN
#
#   retweeted_status.user.geo_enabled  retweeted_status.user.lang  \
# 0                             False                         NaN
# 1                             False                         NaN
# 2                               NaN                         NaN
# 3                             False                         NaN
# 4                              True                         NaN
#
#   retweeted_status.user.contributors_enabled  \
# 0                                      False
# 1                                      False
# 2                                        NaN
# 3                                      False
# 4                                      False
#
#   retweeted_status.user.is_translator  \
# 0                               False
# 1                               False
# 2                                 NaN
# 3                               False
# 4                               False
#
#   retweeted_status.user.profile_background_color  \
# 0                                         000000
# 1                                         F5F8FA
# 2                                            NaN
# 3                                         F5F8FA
# 4                                         C0DEED
#
#   retweeted_status.user.profile_background_image_url  \
# 0   http://abs.twimg.com/images/themes/theme1/bg.png
# 1
# 2                                                NaN
# 3
# 4   http://abs.twimg.com/images/themes/theme1/bg.png
#
#   retweeted_status.user.profile_background_image_url_https  \
# 0        https://abs.twimg.com/images/themes/theme1/bg.png
# 1
# 2                                                      NaN
# 3
# 4        https://abs.twimg.com/images/themes/theme1/bg.png
#
#   retweeted_status.user.profile_background_tile  \
# 0                                         False
# 1                                         False
# 2                                           NaN
# 3                                         False
# 4                                         False
#
#   retweeted_status.user.profile_link_color  \
# 0                                   E20000
# 1                                   1DA1F2
# 2                                      NaN
# 3                                   1DA1F2
# 4                                   1DA1F2
#
#   retweeted_status.user.profile_sidebar_border_color  \
# 0                                             000000
# 1                                             C0DEED
# 2                                                NaN
# 3                                             C0DEED
# 4                                             C0DEED
#
#   retweeted_status.user.profile_sidebar_fill_color  \
# 0                                           000000
# 1                                           DDEEF6
# 2                                              NaN
# 3                                           DDEEF6
# 4                                           DDEEF6
#
#   retweeted_status.user.profile_text_color  \
# 0                                   000000
# 1                                   333333
# 2                                      NaN
# 3                                   333333
# 4                                   333333
#
#   retweeted_status.user.profile_use_background_image  \
# 0                                              False
# 1                                               True
# 2                                                NaN
# 3                                               True
# 4                                               True
#
#                                        retweeted_status.user.profile_image_url  \
# 0  http://pbs.twimg.com/profile_images/1329130767344168968/uRUYAijQ_normal.jpg
# 1  http://pbs.twimg.com/profile_images/1362845270350983170/m6POYjw6_normal.jpg
# 2                                                                          NaN
# 3  http://pbs.twimg.com/profile_images/1349642514261635073/aom800-p_normal.jpg
# 4  http://pbs.twimg.com/profile_images/1350733260771516418/YfS6AdEQ_normal.jpg
#
#                                   retweeted_status.user.profile_image_url_https  \
# 0  https://pbs.twimg.com/profile_images/1329130767344168968/uRUYAijQ_normal.jpg
# 1  https://pbs.twimg.com/profile_images/1362845270350983170/m6POYjw6_normal.jpg
# 2                                                                           NaN
# 3  https://pbs.twimg.com/profile_images/1349642514261635073/aom800-p_normal.jpg
# 4  https://pbs.twimg.com/profile_images/1350733260771516418/YfS6AdEQ_normal.jpg
#
#                                retweeted_status.user.profile_banner_url  \
# 0   https://pbs.twimg.com/profile_banners/846923375209594880/1605717766
# 1  https://pbs.twimg.com/profile_banners/1296870908716634112/1613762810
# 2                                                                   NaN
# 3  https://pbs.twimg.com/profile_banners/1065843842224508928/1610614826
# 4            https://pbs.twimg.com/profile_banners/175198393/1584596438
#
#   retweeted_status.user.default_profile  \
# 0                                 False
# 1                                  True
# 2                                   NaN
# 3                                  True
# 4                                  True
#
#   retweeted_status.user.default_profile_image  \
# 0                                       False
# 1                                       False
# 2                                         NaN
# 3                                       False
# 4                                       False
#
#    retweeted_status.user.following  retweeted_status.user.follow_request_sent  \
# 0                              NaN                                        NaN
# 1                              NaN                                        NaN
# 2                              NaN                                        NaN
# 3                              NaN                                        NaN
# 4                              NaN                                        NaN
#
#    retweeted_status.user.notifications  retweeted_status.geo  \
# 0                                  NaN                   NaN
# 1                                  NaN                   NaN
# 2                                  NaN                   NaN
# 3                                  NaN                   NaN
# 4                                  NaN                   NaN
#
#    retweeted_status.coordinates  retweeted_status.place  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
#
#    retweeted_status.contributors retweeted_status.is_quote_status  \
# 0                            NaN                            False
# 1                            NaN                            False
# 2                            NaN                              NaN
# 3                            NaN                            False
# 4                            NaN                            False
#
#                                                                                                                                                                                                                    retweeted_status.extended_tweet.full_text  \
# 0                                                               WARNING - SPOILERS BELOW:\n\nA brief frame during #WandaVision's new episode offered more insight into #SWORD's plan with #TheVision! Photo: https://t.co/uHw90MVJhh https://t.co/v6mwAEuPU9
# 1                                                                                                                                                                                                                                                        NaN
# 2                                                                                                                                                                                                                                                        NaN
# 3  The new documentary about the late, great Patrice O’Neal premieres tonight on Comedy Central.  We went over some of his lessons about women in episode 162 of the podcast. #PodernFamily #PodNation #PodcastHQ #KillingIsEasy \n\nhttps://t.co/cjIwfyHGCs
# 4                                                                                                                                                                                                                                                        NaN
#
#   retweeted_status.extended_tweet.display_text_range  \
# 0                                           [0, 162]
# 1                                                NaN
# 2                                                NaN
# 3                                           [0, 247]
# 4                                                NaN
#
#                                                                                                                                                  retweeted_status.extended_tweet.entities.hashtags  \
# 0                                                           [{'text': 'WandaVision', 'indices': [48, 60]}, {'text': 'SWORD', 'indices': [101, 107]}, {'text': 'TheVision', 'indices': [120, 130]}]
# 1                                                                                                                                                                                              NaN
# 2                                                                                                                                                                                              NaN
# 3  [{'text': 'PodernFamily', 'indices': [171, 184]}, {'text': 'PodNation', 'indices': [185, 195]}, {'text': 'PodcastHQ', 'indices': [196, 206]}, {'text': 'KillingIsEasy', 'indices': [207, 221]}]
# 4                                                                                                                                                                                              NaN
#
#                                                                                                                                                                          retweeted_status.extended_tweet.entities.urls  \
# 0                                                                             [{'url': 'https://t.co/uHw90MVJhh', 'expanded_url': 'https://buff.ly/2Nem8JT', 'display_url': 'buff.ly/2Nem8JT', 'indices': [139, 162]}]
# 1                                                                                                                                                                                                                  NaN
# 2                                                                                                                                                                                                                  NaN
# 3  [{'url': 'https://t.co/cjIwfyHGCs', 'expanded_url': 'https://open.spotify.com/episode/2pLhSgOIbJyTSWa9d5iQXV?si=iTt_VmhSSxq5-zSXcbeC8A', 'display_url': 'open.spotify.com/episode/2pLhSg…', 'indices': [224, 247]}]
# 4                                                                                                                                                                                                                  NaN
#
#   retweeted_status.extended_tweet.entities.user_mentions  \
# 0                                                     []
# 1                                                    NaN
# 2                                                    NaN
# 3                                                     []
# 4                                                    NaN
#
#   retweeted_status.extended_tweet.entities.symbols  \
# 0                                               []
# 1                                              NaN
# 2                                              NaN
# 3                                               []
# 4                                              NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    retweeted_status.extended_tweet.entities.media  \
# 0  [{'id': 1362833538245083143, 'id_str': '1362833538245083143', 'indices': [163, 186], 'media_url': 'http://pbs.twimg.com/media/EunB4ecWQAczxK8.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EunB4ecWQAczxK8.jpg', 'url': 'https://t.co/v6mwAEuPU9', 'display_url': 'pic.twitter.com/v6mwAEuPU9', 'expanded_url': 'https://twitter.com/MCU_Direct/status/1362833539776081923/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1280, 'h': 720, 'resize': 'fit'}, 'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}, 'small': {'w': 680, 'h': 383, 'resize': 'fit'}}}]
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             NaN
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             NaN
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             NaN
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           retweeted_status.extended_tweet.extended_entities.media  \
# 0  [{'id': 1362833538245083143, 'id_str': '1362833538245083143', 'indices': [163, 186], 'media_url': 'http://pbs.twimg.com/media/EunB4ecWQAczxK8.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EunB4ecWQAczxK8.jpg', 'url': 'https://t.co/v6mwAEuPU9', 'display_url': 'pic.twitter.com/v6mwAEuPU9', 'expanded_url': 'https://twitter.com/MCU_Direct/status/1362833539776081923/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1280, 'h': 720, 'resize': 'fit'}, 'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}, 'small': {'w': 680, 'h': 383, 'resize': 'fit'}}}]
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             NaN
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             NaN
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             NaN
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             NaN
#
#    retweeted_status.quote_count  retweeted_status.reply_count  \
# 0                           3.0                           5.0
# 1                           0.0                           0.0
# 2                           NaN                           NaN
# 3                           0.0                           0.0
# 4                          45.0                          33.0
#
#    retweeted_status.retweet_count  retweeted_status.favorite_count  \
# 0                            57.0                            693.0
# 1                             1.0                              3.0
# 2                             NaN                              NaN
# 3                             1.0                              0.0
# 4                           400.0                           3333.0
#
#                                                          retweeted_status.entities.hashtags  \
# 0  [{'text': 'WandaVision', 'indices': [48, 60]}, {'text': 'SWORD', 'indices': [101, 107]}]
# 1                                                                                        []
# 2                                                                                       NaN
# 3                                                                                        []
# 4                                                                                        []
#
#                                                                                                                                                       retweeted_status.entities.urls  \
# 0  [{'url': 'https://t.co/a1dOZxEgfT', 'expanded_url': 'https://twitter.com/i/web/status/1362833539776081923', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]
# 1                                                                                                                                                                                 []
# 2                                                                                                                                                                                NaN
# 3  [{'url': 'https://t.co/GNnUeglEKO', 'expanded_url': 'https://twitter.com/i/web/status/1362879875099500544', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]
# 4                                   [{'url': 'https://t.co/kTZJ6qpSTb', 'expanded_url': 'https://youtu.be/Wz8mc5Vvl54', 'display_url': 'youtu.be/Wz8mc5Vvl54', 'indices': [34, 57]}]
#
#   retweeted_status.entities.user_mentions retweeted_status.entities.symbols  \
# 0                                      []                                []
# 1                                      []                                []
# 2                                     NaN                               NaN
# 3                                      []                                []
# 4                                      []                                []
#
#   retweeted_status.favorited retweeted_status.retweeted  \
# 0                      False                      False
# 1                      False                      False
# 2                        NaN                        NaN
# 3                      False                      False
# 4                      False                      False
#
#   retweeted_status.possibly_sensitive retweeted_status.filter_level  \
# 0                               False                           low
# 1                               False                           low
# 2                                 NaN                           NaN
# 3                               False                           low
# 4                               False                           low
#
#   retweeted_status.lang  \
# 0                    en
# 1                    en
# 2                   NaN
# 3                    en
# 4                    en
#
#                                                                                                                             entities.hashtags  \
# 0                                                    [{'text': 'WandaVision', 'indices': [64, 76]}, {'text': 'SWORD', 'indices': [117, 123]}]
# 1                                                                                                                                          []
# 2  [{'text': '107DaysOfGenocide', 'indices': [0, 18]}, {'text': 'Ethiopian', 'indices': [45, 55]}, {'text': 'Eritrean', 'indices': [62, 71]}]
# 3                                                                                                                                          []
# 4                                                                                                                                          []
#
#                                                                                                                                                                        entities.urls  \
# 0                                                                                                                                                                                 []
# 1                                                                                                                                                                                 []
# 2  [{'url': 'https://t.co/Mu9CJh405z', 'expanded_url': 'https://twitter.com/i/web/status/1362881466766667786', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [120, 143]}]
# 3                                                                                                                                                                                 []
# 4                                   [{'url': 'https://t.co/kTZJ6qpSTb', 'expanded_url': 'https://youtu.be/Wz8mc5Vvl54', 'display_url': 'youtu.be/Wz8mc5Vvl54', 'indices': [49, 72]}]
#
#                                                                                                                       entities.user_mentions  \
# 0  [{'screen_name': 'MCU_Direct', 'name': 'MCU - The Direct', 'id': 846923375209594880, 'id_str': '846923375209594880', 'indices': [3, 14]}]
# 1            [{'screen_name': 'Joshuagumi', 'name': 'Josh', 'id': 1296870908716634112, 'id_str': '1296870908716634112', 'indices': [3, 14]}]
# 2                                                                                                                                         []
# 3     [{'screen_name': 'TCP_Pod', 'name': 'Lakers (49-14)', 'id': 1065843842224508928, 'id_str': '1065843842224508928', 'indices': [3, 11]}]
# 4        [{'screen_name': 'lilyachty', 'name': 'concrete boy boat/ most hated', 'id': 175198393, 'id_str': '175198393', 'indices': [3, 13]}]
#
#   entities.symbols possibly_sensitive  \
# 0               []                NaN
# 1               []              False
# 2               []                NaN
# 3               []                NaN
# 4               []              False
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   retweeted_status.entities.media  \
# ...
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#    quoted_status.retweet_count  quoted_status.favorite_count  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
#
#   quoted_status.entities.hashtags quoted_status.entities.urls  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
#
#   quoted_status.entities.user_mentions quoted_status.entities.symbols  \
# 0                                  NaN                            NaN
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
# 3                                  NaN                            NaN
# 4                                  NaN                            NaN
#
#   quoted_status.favorited quoted_status.retweeted  \
# 0                     NaN                     NaN
# 1                     NaN                     NaN
# 2                     NaN                     NaN
# 3                     NaN                     NaN
# 4                     NaN                     NaN
#
#   quoted_status.possibly_sensitive quoted_status.filter_level  \
# 0                              NaN                        NaN
# 1                              NaN                        NaN
# 2                              NaN                        NaN
# 3                              NaN                        NaN
# 4                              NaN                        NaN
#
#   quoted_status.lang quoted_status_permalink.url  \
# 0                NaN                         NaN
# 1                NaN                         NaN
# 2                NaN                         NaN
# 3                NaN                         NaN
# 4                NaN                         NaN
#
#   quoted_status_permalink.expanded quoted_status_permalink.display  \
# 0                              NaN                             NaN
# 1                              NaN                             NaN
# 2                              NaN                             NaN
# 3                              NaN                             NaN
# 4                              NaN                             NaN
#
#   retweeted_status.quoted_status.entities.media  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   retweeted_status.quoted_status.extended_entities.media  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
#
#   quoted_status.entities.media quoted_status.extended_entities.media geo.type  \
# 0                          NaN                                   NaN      NaN
# 1                          NaN                                   NaN      NaN
# 2                          NaN                                   NaN      NaN
# 3                          NaN                                   NaN      NaN
# 4                          NaN                                   NaN      NaN
#
#   geo.coordinates coordinates.type coordinates.coordinates place.id place.url  \
# 0             NaN              NaN                     NaN      NaN       NaN
# 1             NaN              NaN                     NaN      NaN       NaN
# 2             NaN              NaN                     NaN      NaN       NaN
# 3             NaN              NaN                     NaN      NaN       NaN
# 4             NaN              NaN                     NaN      NaN       NaN
#
#   place.place_type place.name place.full_name place.country_code  \
# 0              NaN        NaN             NaN                NaN
# 1              NaN        NaN             NaN                NaN
# 2              NaN        NaN             NaN                NaN
# 3              NaN        NaN             NaN                NaN
# 4              NaN        NaN             NaN                NaN
#
#   place.country place.bounding_box.type place.bounding_box.coordinates  \
# 0           NaN                     NaN                            NaN
# 1           NaN                     NaN                            NaN
# 2           NaN                     NaN                            NaN
# 3           NaN                     NaN                            NaN
# 4           NaN                     NaN                            NaN
#
#   extended_tweet.entities.media extended_tweet.extended_entities.media  \
# 0                           NaN                                    NaN
# 1                           NaN                                    NaN
# 2                           NaN                                    NaN
# 3                           NaN                                    NaN
# 4                           NaN                                    NaN
#
#   retweeted_status.scopes.followers retweeted_status.place.id  \
# 0                               NaN                       NaN
# 1                               NaN                       NaN
# 2                               NaN                       NaN
# 3                               NaN                       NaN
# 4                               NaN                       NaN
#
#   retweeted_status.place.url retweeted_status.place.place_type  \
# 0                        NaN                               NaN
# 1                        NaN                               NaN
# 2                        NaN                               NaN
# 3                        NaN                               NaN
# 4                        NaN                               NaN
#
#   retweeted_status.place.name retweeted_status.place.full_name  \
# 0                         NaN                              NaN
# 1                         NaN                              NaN
# 2                         NaN                              NaN
# 3                         NaN                              NaN
# 4                         NaN                              NaN
#
#   retweeted_status.place.country_code retweeted_status.place.country  \
# 0                                 NaN                            NaN
# 1                                 NaN                            NaN
# 2                                 NaN                            NaN
# 3                                 NaN                            NaN
# 4                                 NaN                            NaN
#
#   retweeted_status.place.bounding_box.type  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   retweeted_status.place.bounding_box.coordinates  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   retweeted_status.quoted_status.place.id  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   retweeted_status.quoted_status.place.url  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   retweeted_status.quoted_status.place.place_type  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   retweeted_status.quoted_status.place.name  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   retweeted_status.quoted_status.place.full_name  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   retweeted_status.quoted_status.place.country_code  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#   retweeted_status.quoted_status.place.country  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   retweeted_status.quoted_status.place.bounding_box.type  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
#
#   retweeted_status.quoted_status.place.bounding_box.coordinates  \
# 0                                                           NaN
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                           NaN
#
#    retweeted_status.quoted_status.quoted_status_id  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   retweeted_status.quoted_status.quoted_status_id_str quoted_status.place.id  \
# 0                                                 NaN                    NaN
# 1                                                 NaN                    NaN
# 2                                                 NaN                    NaN
# 3                                                 NaN                    NaN
# 4                                                 NaN                    NaN
#
#   quoted_status.place.url quoted_status.place.place_type  \
# 0                     NaN                            NaN
# 1                     NaN                            NaN
# 2                     NaN                            NaN
# 3                     NaN                            NaN
# 4                     NaN                            NaN
#
#   quoted_status.place.name quoted_status.place.full_name  \
# 0                      NaN                           NaN
# 1                      NaN                           NaN
# 2                      NaN                           NaN
# 3                      NaN                           NaN
# 4                      NaN                           NaN
#
#   quoted_status.place.country_code quoted_status.place.country  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4                              NaN                         NaN
#
#   quoted_status.place.bounding_box.type  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   quoted_status.place.bounding_box.coordinates  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    quoted_status.quoted_status_id quoted_status.quoted_status_id_str  \
# 0                             NaN                                NaN
# 1                             NaN                                NaN
# 2                             NaN                                NaN
# 3                             NaN                                NaN
# 4                             NaN                                NaN
#
#   quoted_status.scopes.followers retweeted_status.geo.type  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# 2                            NaN                       NaN
# 3                            NaN                       NaN
# 4                            NaN                       NaN
#
#   retweeted_status.geo.coordinates retweeted_status.coordinates.type  \
# 0                              NaN                               NaN
# 1                              NaN                               NaN
# 2                              NaN                               NaN
# 3                              NaN                               NaN
# 4                              NaN                               NaN
#
#   retweeted_status.coordinates.coordinates quoted_status.geo.type  \
# 0                                      NaN                    NaN
# 1                                      NaN                    NaN
# 2                                      NaN                    NaN
# 3                                      NaN                    NaN
# 4                                      NaN                    NaN
#
#   quoted_status.geo.coordinates quoted_status.coordinates.type  \
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                           NaN                            NaN
#
#   quoted_status.coordinates.coordinates  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#                                                 url
# 0  https://twitter.com/_/status/1362881462073188363
# 1  https://twitter.com/_/status/1362881462748524548
# 2  https://twitter.com/_/status/1362881466766667786
# 3  https://twitter.com/_/status/1362881471409770496
# 4  https://twitter.com/_/status/1362881480930717699

# %%
# Convert to list
data = df.text.values.tolist()

# Remove users names
data = [re.sub('@[^\s]+', '', sent) for sent in data]

#Remove links
data = [re.sub('((www\.[^\s]+)|(https?://[^\s]+))','',sent) for sent in data]

#Remove new line characters
data = [re.sub('\s+', ' ', sent) for sent in data]


pprint(data[:5])
# Out:
# ["RT WARNING - SPOILERS BELOW: A brief frame during #WandaVision's new episode "
#  "offered more insight into #SWORD's plan with #Th…",
#  'RT New JJK episode had me sketching 😼 ',
#  '#107DaysOfGenocide since joint forces of the #Ethiopian &amp; #Eritrean '
#  'gov’ts started to exterminate ethnic Tigrayans… ',
#  'RT The new documentary about the late, great Patrice O’Neal premieres '
#  'tonight on Comedy Central. We went over some of his lesson…',
#  'RT ALSO NEW EPISODE OF THE BOAT SHOW ']

# %% [markdown]
# ## Study of most and least frequent words
#
# Most frequent words contain the words we used for the search, as expected, the search words will be deleted from the search afterwards. However, in the most frequent words there is some relevant information and we shouln't delete all of them.
#
# For the least frequent words we find non-sense expressions, mostly users names, that would mess up our topic modelling, so we delete the 100 less  used words.

# %%
# Extract tokens, generate count vectors and remove stopwords
tokenizer = RegexpTokenizer(r'[a-zA-Z]+')

word_vec3 = df['text'].apply(str.lower).apply(tokenizer.tokenize).apply(pd.value_counts).fillna(0)

word_vec3 = word_vec3.drop(stopwords.words('english')+['https','co', 'rt'], axis=1, errors='ignore').fillna(0)
    
# Compute term frequencies
tf3 = word_vec3.divide(np.sum(word_vec3, axis=1), axis=0)

tf_dict3 = {}
for column in tf3:  
  tf_dict3[column] = tf3[column].sum()
print(len(tf_dict3))
tf_words3 = sorted(tf_dict3.items(), key=lambda item: item[1], reverse=True)[:10]
labels3  = [w[0] for w in tf_words3]
values3  = [w[1] for w in tf_words3]
indexes3 = np.arange(len(labels3))

print(labels3)

f3, ax3 = plt.subplots(figsize=(20,5))
cmap = plt.cm.tab10
plt.bar(indexes3, values3, color=cmap(np.arange(len(df)) % cmap.N))
plt.xticks(indexes3, labels3)
plt.title('Words by TF', fontsize=20)
plt.show()
# Out:
# 7891
# ['new', 'episode', 'movie', 'film', 'wandavision', 'podcast', 'check', 'watch', 'amp', 'tonight']

# %%
tf_wordsless = sorted(tf_dict3.items(), key=lambda item: item[1], reverse=False)[:100]
labelsless  = [w[0] for w in tf_wordsless]
values3  = [w[1] for w in tf_wordsless]
indexes3 = np.arange(len(labelsless))

print('least frequent words',labelsless)
# Out:
# least frequent words ['dalmatians', 'themesnark', 'vgybnpq', 'mv', 'lyric', 'land', 'ryu', 'icons', 'mxtga', 'epic', 'eoiz', 'reichl', 'revops', 'prbc', 'saas', 'nimbly', 'plp', 'ber', 'teen', 'fd', 'backdrops', 'titans', 'named', 'lockdown', 'amadea', 'planet', 'jasonmanford', 'cornetto', 'spider', 'liked', 'pegg', 'fab', 'friendliest', 'heyo', 'ckvw', 'hav', 'costner', 'sela', 'kutcher', 'josephdemauro', 'ashton', 'ward', 'guardian', 'ww', 'nl', 'znlnbvhf', 'text', 'nouveau', 'placebo', 'jfc', 'somehow', 'iona', 'hsj', 'fpx', 'pagmyst', 'thecartooncrave', 'max', 'infinity', 'upfront', 'highlights', 'ahjmly', 'tears', 'electricjazzcat', 'vu', 'vmkw', 'soda', 'uo', 'fiizz', 'unbound', 'beasting', 'machine', 'washing', 'protex', 'wniqorudbc', 'degrees', 'aeg', 'lavamat', 'rinse', 'uvdywwmu', 'tah', 'mooh', 'lay', 'newcomer', 'pol', 'humpday', 'menatplaycom', 'rosso', 'leor', 'leo', 'prince', 'yvrshoots', 'vancouver', 'maclaine', 'dinklage', 'shirley', 'dreamer', 'indie', 'vjsks', 'azumi', 'uye']

# %% [markdown]
# # Preparation and clean-up for data

# %% [markdown]
# ## Prepare Stopwords (different!)
# We import the english stopwords and, together with least frequent words, the search words and other expressions, we make it available in stop_words.

# %%
# NLTK Stop words
stop_words = stopwords.words('english')

delete_words = []

#Search words
delete_words.append('new')
delete_words.append('episode')
delete_words.append('premiere')
delete_words.append('check')
delete_words.append('watch')

#least frequent words
delete_words_full = delete_words + labelsless

#other expressions
stop_words.extend(['rt', 'https', 'co'])
stop_words.extend(delete_words_full)

# %% [markdown]
# ## Tokenize words and Clean-up text (from the lab)
#
# Tokenize each sentence into a list of words, removing punctuations and unnecessary characters altogether.
#
# Gensim’s _simple_preprocess()_ is great for this. Additionally I have set _deacc=True_ to remove the punctuations.

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

print(data_words[:1])
# Out:
# [['rt', 'warning', 'spoilers', 'below', 'brief', 'frame', 'during', 'wandavision', 'new', 'episode', 'offered', 'more', 'insight', 'into', 'sword', 'plan', 'with', 'th']]

# %% [markdown]
# ## Creating Bigram and Trigram Models (from the lab)
#
# Gensim’s _Phrases_ model can build and implement the bigrams, trigrams, quadgrams and more. The two important arguments to _Phrases_ are _min_count_ and _threshold_. The higher the values of these param, the harder it is for words to be combined to bigrams.

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# See trigram example
print([g for g in trigram_mod[bigram_mod[data_words[0]]] if '_'  in g])
# Out:
# /usr/local/lib/python3.7/dist-packages/gensim/models/phrases.py:598: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")
# []

# %% [markdown]
# ## Remove Stopwords, Make Bigrams and Lemmatize (from the lab)
#
# Definition of the functions to remove the stopwords, make bigrams and lemmatization and call them sequentially.

# %%
# Define functions for stopwords, bigrams, trigrams and lemmatization
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %% [markdown]
# Let’s call the functions in order.

# %%
# Remove Stop Words
data_words_nostops = remove_stopwords(data_words)

# Form Bigrams
data_words_bigrams = make_bigrams(data_words_nostops)

# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
# python3 -m spacy download en
nlp = spacy.load('en', disable=['parser', 'ner'])

# Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized = lemmatization(data_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])

print(data_lemmatized[:5])
# Out:
# [['warning', 'wandavision', 'offer', 'insight', 'sword', 'plan'], [], ['eritrean_gov', 'ts_starte', 'exterminate_ethnic', 'tigrayan'], ['documentary', 'late', 'great', 'patrice', 'neal', 'premiere', 'tonight', 'comedy', 'central', 'go', 'lesson'], ['also']]

# %% [markdown]
# # Preparation and building the model
#
# We use the code used in the lab

# %% [markdown]
# ## Create the Dictionary and Corpus needed for Topic Modeling
#
# The two main inputs to the LDA topic model are the dictionary(id2word) and the corpus. Let’s create them.

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_lemmatized)

# Create Corpus
texts = data_lemmatized

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# View
print(corpus[:1])
# Out:
# [[(0, 1), (1, 1), (2, 1), (3, 1), (4, 1), (5, 1)]]

# %% [markdown]
# ##  Building LDA Mallet Model
# So far you have seen Gensim’s inbuilt version of the LDA algorithm. Mallet’s version, however, often gives a better quality of topics.
#
# Gensim provides a wrapper to implement Mallet’s LDA from within Gensim itself. You only need to download the zipfile, unzip it and provide the path to mallet in the unzipped directory to _gensim.models.wrappers.LdaMallet_. See how I have done this below.

# %%
# !wget http://mallet.cs.umass.edu/dist/mallet-2.0.8.zip
# !unzip mallet-2.0.8.zip
# Out:
# --2021-03-10 20:54:16--  http://mallet.cs.umass.edu/dist/mallet-2.0.8.zip
# Resolving mallet.cs.umass.edu (mallet.cs.umass.edu)... 128.119.246.70
# Connecting to mallet.cs.umass.edu (mallet.cs.umass.edu)|128.119.246.70|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16184794 (15M) [application/zip]
# Saving to: ‘mallet-2.0.8.zip.2’
#
# mallet-2.0.8.zip.2  100%[===================>]  15.43M  13.9MB/s    in 1.1s
#
# 2021-03-10 20:54:17 (13.9 MB/s) - ‘mallet-2.0.8.zip.2’ saved [16184794/16184794]
#
# Archive:  mallet-2.0.8.zip
# replace mallet-2.0.8/bin/classifier2info? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %% [markdown]
# ## Optimal number of topics for LDA
#
# Approach: build many LDA models with different values of number of topics (k) and pick the one that gives the highest coherence value.
#
# Choosing a ‘k’ that marks the end of a rapid growth of topic coherence usually offers meaningful and interpretable topics. Picking an even higher value can sometimes provide more granular sub-topics.
#
# If you see the same keywords being repeated in multiple topics, it’s probably a sign that the ‘k’ is too large.
#
# The _compute_coherence_values()_ (see below) trains multiple LDA models and provides the models and their corresponding coherence scores.

# %%
mallet_path = 'mallet-2.0.8/bin/mallet' # update this path
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=num_topics, id2word=id2word)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values

# %%
# Can take a long time to run.
model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=data_lemmatized, start=2, limit=14, step=1)

# %%
# Show graph
limit=14; start=2; step=1;
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.title('Finding optimal number of topics')
plt.savefig('coherence19feb.png')
plt.show()

# %%
# Print the coherence scores
for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4))
# Out:
# Num Topics = 2  has Coherence Value of 0.5446
# Num Topics = 3  has Coherence Value of 0.5868
# Num Topics = 4  has Coherence Value of 0.585
# Num Topics = 5  has Coherence Value of 0.5849
# Num Topics = 6  has Coherence Value of 0.5758
# Num Topics = 7  has Coherence Value of 0.5749
# Num Topics = 8  has Coherence Value of 0.5766
# Num Topics = 9  has Coherence Value of 0.5686
# Num Topics = 10  has Coherence Value of 0.589
# Num Topics = 11  has Coherence Value of 0.5925
# Num Topics = 12  has Coherence Value of 0.566
# Num Topics = 13  has Coherence Value of 0.575

# %% [markdown]
# We choose the maximum coherence (11), but we also explore other numbers.

# %%
# Select the model and print the topics
optimal_model = model_list[9]
model_topics = optimal_model.show_topics(formatted=True)
pprint(optimal_model.print_topics(num_words=15))
# Out:
# [(0,
#   '0.107*"tonight" + 0.066*"love" + 0.061*"late" + 0.042*"great" + 0.042*"day" '
#   '+ 0.042*"thing" + 0.028*"world" + 0.027*"chat" + 0.017*"documentary" + '
#   '0.017*"big_night" + 0.016*"spend" + 0.015*"outage" + 0.014*"cool" + '
#   '0.014*"thereidout" + 0.012*"hear"'),
#  (1,
#   '0.339*"film" + 0.053*"music" + 0.051*"project" + 0.049*"currently_looke" + '
#   '0.049*"game_animation" + 0.045*"gl" + 0.013*"visit_http" + '
#   '0.013*"rainsdowne_players" + 0.008*"poster" + 0.008*"thenew" + '
#   '0.008*"literally" + 0.008*"artist" + 0.007*"surprise" + 0.007*"hire" + '
#   '0.007*"light"'),
#  (2,
#   '0.058*"join" + 0.051*"good" + 0.038*"year" + 0.022*"set" + 0.022*"lot" + '
#   '0.021*"bad" + 0.020*"movie" + 0.020*"remake" + 0.017*"put" + 0.016*"boy" + '
#   '0.015*"franchise" + 0.015*"stuff" + 0.015*"forget" + 0.014*"speak" + '
#   '0.012*"icymi"'),
#  (3,
#   '0.169*"podcast" + 0.081*"time" + 0.071*"listen" + 0.042*"discuss" + '
#   '0.041*"work" + 0.031*"stream" + 0.024*"character" + 0.020*"end" + '
#   '0.014*"finally" + 0.013*"issue" + 0.011*"video" + 0.010*"version" + '
#   '0.010*"publish" + 0.010*"meet" + 0.009*"fun"'),
#  (4,
#   '0.082*"watch" + 0.065*"live" + 0.061*"favorite" + 0.046*"genre" + '
#   '0.043*"bobcore" + 0.026*"share" + 0.025*"feel" + 0.021*"tweet" + '
#   '0.020*"honor" + 0.018*"song" + 0.017*"dark" + 0.013*"follow" + '
#   '0.012*"episode" + 0.010*"cast" + 0.010*"line"'),
#  (5,
#   '0.060*"show" + 0.053*"supergirl" + 0.053*"young" + 0.044*"dc_universe" + '
#   '0.028*"original" + 0.024*"pick" + 0.022*"season" + 0.020*"tomorrow" + '
#   '0.018*"full" + 0.017*"enjoy" + 0.017*"tune" + 0.016*"game" + 0.015*"ready" '
#   '+ 0.015*"action" + 0.015*"give"'),
#  (6,
#   '0.301*"wandavision" + 0.070*"release" + 0.060*"spoiler" + '
#   '0.044*"wanda_thevision" + 0.028*"impact" + 0.027*"word" + 0.026*"amazing" + '
#   '0.024*"reveal" + 0.019*"power" + 0.018*"hope" + 0.010*"cat" + '
#   '0.010*"powerful_avenger" + 0.010*"king" + 0.010*"yup" + 0.009*"scene"'),
#  (7,
#   '0.326*"movie" + 0.085*"make" + 0.033*"trailer" + 0.029*"video" + '
#   '0.028*"guest" + 0.022*"uhg" + 0.022*"skydance" + 0.020*"cover" + '
#   '0.018*"special" + 0.013*"trustmovie" + 0.013*"owen" + 0.012*"hard" + '
#   '0.011*"support" + 0.011*"art" + 0.009*"great"'),
#  (8,
#   '0.077*"brand" + 0.064*"today" + 0.057*"feature" + 0.044*"back" + '
#   '0.032*"drop" + 0.024*"friend" + 0.024*"send" + 0.022*"people" + '
#   '0.018*"long" + 0.017*"link" + 0.017*"break" + 0.012*"couple" + '
#   '0.011*"family" + 0.011*"expe" + 0.010*"free"'),
#  (9,
#   '0.098*"talk" + 0.047*"accountability" + 0.041*"terrify" + '
#   '0.040*"republicans_complain" + 0.032*"find" + 0.030*"life" + 0.028*"big" + '
#   '0.025*"night" + 0.025*"start" + 0.022*"play" + 0.016*"story" + 0.014*"hit" '
#   '+ 0.014*"flash" + 0.014*"win" + 0.013*"guy"'),
#  (10,
#   '0.078*"film" + 0.077*"week" + 0.076*"amp" + 0.038*"bring" + 0.034*"wait" + '
#   '0.032*"direct" + 0.026*"business" + 0.024*"job" + 0.021*"support_existe" + '
#   '0.021*"mone" + 0.019*"team" + 0.014*"goldfinger" + 0.013*"adaptation" + '
#   '0.011*"running_man" + 0.011*"call"')]

# %%
# Compute Coherence Score
coherence_model_ldamallet = CoherenceModel(model=optimal_model, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_ldamallet = coherence_model_ldamallet.get_coherence()
print('\nCoherence Score: ', coherence_ldamallet)
# Out:
# Coherence Score:  0.59246495877583

# %% [markdown]
# # Study model (from the lab)

# %% [markdown]
# ## Finding the dominant topic in each sentence
#
# One of the practical application of topic modeling is to determine what topic a given document is about.
#
# To find that, we find the topic number that has the highest percentage contribution in that document.
#
# The _format_topics_sentences()_ function below nicely aggregates this information in a presentable table.

# %%
def format_topics_sentences(ldamodel=optimal_model, corpus=corpus, texts=data):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(ldamodel=optimal_model, corpus=corpus, texts=data)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']

# Show
pd.set_option('display.max_colwidth', -1)
df_dominant_topic[['Keywords','Text']].head(20)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#                                                                                                         Keywords  \
# 0   wandavision, release, spoiler, wanda_thevision, impact, word, amazing, reveal, power, hope
# 1   tonight, love, late, great, day, thing, world, chat, big_night, documentary
# 2   watch, live, favorite, genre, bobcore, share, feel, tweet, honor, song
# 3   tonight, love, late, great, day, thing, world, chat, big_night, documentary
# 4   tonight, love, late, great, day, thing, world, chat, big_night, documentary
# 5   wandavision, release, spoiler, wanda_thevision, impact, word, amazing, reveal, power, hope
# 6   wandavision, release, spoiler, wanda_thevision, impact, word, amazing, reveal, power, hope
# 7   tonight, love, late, great, day, thing, world, chat, big_night, documentary
# 8   tonight, love, late, great, day, thing, world, chat, big_night, documentary
# 9   movie, make, trailer, video, guest, uhg, skydance, cover, special, trustmovie
# 10  movie, make, trailer, video, guest, uhg, skydance, cover, special, trustmovie
# 11  tonight, love, late, great, day, thing, world, chat, big_night, documentary
# 12  watch, live, favorite, genre, bobcore, share, feel, tweet, honor, song
# 13  tonight, love, late, great, day, thing, world, chat, big_night, documentary
# 14  tonight, love, late, great, day, thing, world, chat, big_night, documentary
# 15  show, young, supergirl, dc_universe, original, pick, season, tomorrow, full, tune
# 16  join, good, year, set, lot, bad, movie, remake, put, boy
# 17  tonight, love, late, great, day, thing, world, chat, big_night, documentary
# 18  tonight, love, late, great, day, thing, world, chat, big_night, documentary
# 19  film, music, project, currently_looke, game_animation, gl, rainsdowne_players, visit_http, literally, poster
#
#                                                                                                                                   Text
# 0   RT WARNING - SPOILERS BELOW: A brief frame during #WandaVision's new episode offered more insight into #SWORD's plan with #Th…
# 1   RT New JJK episode had me sketching 😼
# 2   #107DaysOfGenocide since joint forces of the #Ethiopian &amp; #Eritrean gov’ts started to exterminate ethnic Tigrayans…
# 3   RT The new documentary about the late, great Patrice O’Neal premieres tonight on Comedy Central. We went over some of his lesson…
# 4   RT ALSO NEW EPISODE OF THE BOAT SHOW
# 5   RT Edward is the first Southern white rhino to be born via artificial insemination in North America at the It'…
# 6   RT #wandavision #MonicaRambeau new episode 7 spoilers , the way carol’s words had such a long lasting impact on monica and help…
# 7   RT The new documentary about the late, great Patrice O’Neal premieres tonight on Comedy Central. We went over some of his le…
# 8    i hope she’s in the new captain marvel movie too, that would be so cool she’s a really cool character
# 9   RT #TheHardyBoys go under cover at a New England college where three coeds have been kidnapped when #ValerieBertinelli guest…
# 10  RT This Flash movie is basically restarting the DCEU with new and old. Can’t wait to see Supergirl on the big screen... no…
# 11  RT The new documentary about the late, great Patrice O’Neal premieres tonight on Comedy Central. We went over some of his lesson…
# 12  I can’t wait until she finishes this movie.... words will be said, and I will be living✨
# 13  RT “Don’t Sweat The Technique” (ft. Tom Cat &amp; Jerry Mouse) Or “another new Tom and Jerry Movie clip”. This is honestl…
# 14  RT The new documentary about the late, great Patrice O’Neal premieres tonight on Comedy Central. We went over some of his le…
# 15   will be the✨ FIRST LATINA✨ Supergirl ever in the DC universe! 🙌🏾👏🏾 #Supergirl #FlashFilm…
# 16  HELLO, GOOD MORNING TO #JUJUTSUKAISEN 'S NEW EPISODE I MUST PROTECC INUMAKI TOGE 🥺
# 17  RT The new documentary about the late, great Patrice O’Neal premieres tonight on Comedy Central. We went over some of his lesson…
# 18  Trust me you don’t wanna miss out
# 19  RT 🎥 𝙎𝙞𝙧 𝘼𝙡𝙚𝙭 𝙁𝙚𝙧𝙜𝙪𝙨𝙤𝙣: 𝙉𝙚𝙫𝙚𝙧 𝙂𝙞𝙫𝙚 𝙄𝙣 A new film about our legendary manager will be in UK cinemas from 27 May and coming soon gl…

# %% [markdown]
# ## Find the most representative document for each topic
#
# Sometimes just the topic keywords may not be enough to make sense of what a topic is about. So, to help with understanding the topic, you can find the documents a given topic has contributed to the most and infer the topic by reading that document.

# %%
# Group top 5 sentences under each topic
sent_topics_sorteddf_mallet = pd.DataFrame()

sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf_mallet = pd.concat([sent_topics_sorteddf_mallet, 
                                             grp.sort_values(['Perc_Contribution'], ascending=[0]).head(1)], 
                                            axis=0)

# Reset Index    
sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)

# Format
sent_topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Text"]

# Show
pd.set_option('display.max_colwidth', None)
sent_topics_sorteddf_mallet.head(12)
# Out:
#     Topic_Num  Topic_Perc_Contrib  \
# 0         0.0              0.2424
# 1         1.0              0.2026
# 2         2.0              0.2163
# 3         3.0              0.1991
# 4         4.0              0.2026
# 5         5.0              0.1705
# 6         6.0              0.1883
# 7         7.0              0.1883
# 8         8.0              0.2548
# 9         9.0              0.2163
# 10       10.0              0.2106
#
#                                                                                                         Keywords  \
# 0                                    tonight, love, late, great, day, thing, world, chat, big_night, documentary
# 1   film, music, project, currently_looke, game_animation, gl, rainsdowne_players, visit_http, literally, poster
# 2                                                       join, good, year, set, lot, bad, movie, remake, put, boy
# 3                                   podcast, time, listen, discuss, work, stream, character, end, finally, issue
# 4                                         watch, live, favorite, genre, bobcore, share, feel, tweet, honor, song
# 5                              show, young, supergirl, dc_universe, original, pick, season, tomorrow, full, tune
# 6                     wandavision, release, spoiler, wanda_thevision, impact, word, amazing, reveal, power, hope
# 7                                  movie, make, trailer, video, guest, uhg, skydance, cover, special, trustmovie
# 8                                            brand, today, feature, back, drop, friend, send, people, long, link
# 9                       talk, accountability, terrify, republicans_complain, find, life, big, night, start, play
# 10                                     film, week, amp, bring, wait, direct, business, job, support_existe, mone
#
#                                                                                                                                   Text
# 0    RT The new documentary about the late, great Patrice O’Neal premieres tonight on Comedy Central. We went over some of his lesson…
# 1                Currently looking for new game, animation, and film 🎵 projects! Check out my music in The Rainsdowne Players! Visit…
# 2                                  RT another piece on celebrating his 10 year anniversary put together by and I speak a lil bit abou…
# 3      RT Leftists have been burned many times by Hollywood depictions—so it’s a welcome surprise when mainstream filmmakers actually…
# 4          RT as a person who is totally still afraid of the dark, it’s an honor to share that my song “around your room” is in a new…
# 5                           RT PLANET LOCKDOWN: DR CARRIE MADEJ FULL INTERVIEW Dr. Carrie Madej - one hour interview, part of full-le…
# 6     RT #wandavision #wandavision10s new episode 7 spoilers , MONICA RAMBEAU’S EYES GLOW YUP SHE’S IN THE MOST POWERFUL AVENGERS CAT…
# 7                         I don’t remember much but like I remember it was awesome. Recreating a movie isn’t really just recreating,…
# 8       RT Lost about 20 friends/nursed 2. No health insurance. Relationships decades long had to break up. People had to go back hom…
# 9         RT ‘I’m fed up with some of the old labels ... I’m fed up being described in simplistic terms that do not capture the compl…
# 10  RT Friendly reminder that wanted to film #Walker in Austin in part to support existing businesses &amp; bring new jobs &amp; mone…
